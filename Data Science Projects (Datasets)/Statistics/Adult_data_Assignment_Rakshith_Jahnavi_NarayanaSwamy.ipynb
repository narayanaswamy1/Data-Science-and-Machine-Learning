# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

# %%
#df = pd.read_csv('adult.data')

# %% [markdown]
# ## Loading the data from a .csv/.data file and replacing '?' with NaN and Printing

# %%
df = pd.read_csv('adult.data', sep=',\s' ,na_values=['?'])
df
# Out:
# C:\Users\Narayana Swamy\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#        age         workclass  fnlwgt     education  education-num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# ...

# %% [markdown]
# ## replacing columns having space with underscore and Printing

# %%
df.columns = [c.replace('-', '_') for c in df.columns]
df
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# ...

# %% [markdown]
# ## plot of dataframe

# %%
df.plot()

# %% [markdown]
# ## checking (rows,columns)

# %%
df.shape
# Out:
# (32561, 15)

# %% [markdown]
# ## calculating total no of NaN values in each columns in the dataframe

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education_num        0
# marital_status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country     583
# 50k a year           0
# dtype: int64

# %% [markdown]
# ## calculating % of NaN values in each columns

# %%
round(df.isnull().sum()/100,2)
# Out:
# age                0.00
# workclass         18.36
# fnlwgt             0.00
# education          0.00
# education_num      0.00
# marital_status     0.00
# occupation        18.43
# relationship       0.00
# race               0.00
# sex                0.00
# capital_gain       0.00
# capital_loss       0.00
# hours_per_week     0.00
# native_country     5.83
# 50k a year         0.00
# dtype: float64

# %% [markdown]
# ## calculating various parameters of the data frame

# %%
df.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# ## calculating what type of data is present in the each column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         30725 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education_num     32561 non-null int64
# marital_status    32561 non-null object
# occupation        30718 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital_gain      32561 non-null int64
# capital_loss      32561 non-null int64
# hours_per_week    32561 non-null int64
# native_country    31978 non-null object
# 50k a year        32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# ## replacing all NaN with the 'ffill'

# %%
df.fillna(method='ffill',inplace=True)

# %% [markdown]
# ## printing dataframe after replacing all NaN values

# %%
df
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# ...

# %%
#df.applymap(lambda x: np.nan if x == '?' else x)

# %% [markdown]
# ## after replacing all NaN values, verifying the dataframe

# %%
round(df.isnull().sum()/100,2)
# Out:
# age               0.0
# workclass         0.0
# fnlwgt            0.0
# education         0.0
# education_num     0.0
# marital_status    0.0
# occupation        0.0
# relationship      0.0
# race              0.0
# sex               0.0
# capital_gain      0.0
# capital_loss      0.0
# hours_per_week    0.0
# native_country    0.0
# 50k a year        0.0
# dtype: float64

# %% [markdown]
# ## calculating skew for all the columns with integer value

# %%
df.skew()
# Out:
# age                0.558743
# fnlwgt             1.446980
# education_num     -0.311676
# capital_gain      11.953848
# capital_loss       4.594629
# hours_per_week     0.227643
# dtype: float64

# %% [markdown]
# ## calculating kurtosis for all the columns with integer value

# %%
df.kurtosis()
# Out:
# age                -0.166127
# fnlwgt              6.218811
# education_num       0.623444
# capital_gain      154.799438
# capital_loss       20.376802
# hours_per_week      2.916687
# dtype: float64

# %% [markdown]
# ## boxplot for all the columns of the dataframe

# %%
df.boxplot()

# %% [markdown]
# ## plot of Age Column

# %%
plt.plot(df.age)

# %% [markdown]
# ## plot of fnlwgt(final weight)

# %%
plt.plot(df.fnlwgt)

# %% [markdown]
# ## plot of education column

# %%
plt.plot(df.education_num)

# %% [markdown]
# ## plot of capital_gain column

# %%
plt.plot(df.capital_gain)

# %% [markdown]
# ## plot of capital_loss column

# %%
plt.plot(df.capital_loss)

# %% [markdown]
# ## plot of hours_per_week column

# %%
plt.plot(df.hours_per_week)

# %% [markdown]
# ## calculating iqr for Age column

# %%
stats.iqr(df.age)
# Out:
# 20.0

# %% [markdown]
# ## calculating iqr for fnlwgt column

# %%
stats.iqr(df.fnlwgt)
# Out:
# 119224.0

# %% [markdown]
# ## boxplot of fnlwgt column

# %%
sns.boxplot(df.fnlwgt)

# %% [markdown]
# ## boxplot of age column

# %%
sns.boxplot(df.age)

# %% [markdown]
# ## boxplot of education_num column

# %%
sns.boxplot(df.education_num)

# %% [markdown]
# ## boxplot of capital_gain column

# %%
sns.boxplot(df.capital_gain)

# %% [markdown]
# ## boxplot of capital_loss column

# %%
sns.boxplot(df.capital_loss)

# %% [markdown]
# ## boxplot of hours_per_week column

# %%
sns.boxplot(df.hours_per_week)

# %%
# calculating rows with value = 0
df[df['capital_gain']==0].shape
# Out:
# (29849, 15)

# %%
# calculating rows with value != 0
df[df['capital_loss']!=0].shape
# Out:
# (1519, 15)
