# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

# %% [markdown]
# ## Laoding and fetching data from a .csv file

# %%
df = pd.read_csv('food-consumption.csv')
df
# Out:
#         Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0       Germany           90              49   88       19.0      57.0
# 1         Italy           82              10   60        2.0      55.0
# 2        France           88              42   63        4.0      76.0
# 3       Holland           96              62   98       32.0      62.0
# 4       Belgium           94              38   48       11.0      74.0
# 5    Luxembourg           97              61   86       28.0      79.0
# 6       England           27              86   99       22.0      91.0
# 7      Portugal           72              26   77        2.0      22.0
# 8       Austria           55              31   61       15.0      29.0
# 9   Switzerland           73              72   85       25.0      31.0
# 10       Sweden           97              13   93       31.0       NaN
# 11      Denmark           96              17   92       35.0      66.0
# ...

# %% [markdown]
# ## replacing column names having spaces with underscore

# %%
df.columns = [c.replace(' ', '_') for c in df.columns]

# %% [markdown]
# ## displaying dataframe with new names

# %%
df
# Out:
#         Country  Real_coffee  Instant_coffee  Tea  Sweetener  Biscuits  \
# 0       Germany           90              49   88       19.0      57.0
# 1         Italy           82              10   60        2.0      55.0
# 2        France           88              42   63        4.0      76.0
# 3       Holland           96              62   98       32.0      62.0
# 4       Belgium           94              38   48       11.0      74.0
# 5    Luxembourg           97              61   86       28.0      79.0
# 6       England           27              86   99       22.0      91.0
# 7      Portugal           72              26   77        2.0      22.0
# 8       Austria           55              31   61       15.0      29.0
# 9   Switzerland           73              72   85       25.0      31.0
# 10       Sweden           97              13   93       31.0       NaN
# 11      Denmark           96              17   92       35.0      66.0
# ...

# %% [markdown]
# ## checking for (rows, columns)

# %%
df.shape
# Out:
# (16, 21)

# %% [markdown]
# ## checking for type of data present in different columns in the .csv file

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 21 columns):
# Country           16 non-null object
# Real_coffee       16 non-null int64
# Instant_coffee    16 non-null int64
# Tea               16 non-null int64
# Sweetener         15 non-null float64
# Biscuits          15 non-null float64
# Powder_soup       16 non-null int64
# Tin_soup          16 non-null int64
# Potatoes          16 non-null int64
# Frozen_fish       16 non-null int64
# Frozen_veggies    16 non-null int64
# Apples            16 non-null int64
# Oranges           16 non-null int64
# Tinned_fruit      16 non-null int64
# Jam               16 non-null int64
# Garlic            16 non-null int64
# Butter            16 non-null int64
# Margarine         16 non-null int64
# Olive_oil         16 non-null int64
# Yoghurt           15 non-null float64
# Crisp_bread       16 non-null int64
# dtypes: float64(3), int64(17), object(1)
# memory usage: 2.7+ KB

# %% [markdown]
# ## calculating various parameters in the dataframe

# %%
df.describe()
# Out:
#        Real_coffee  Instant_coffee        Tea  Sweetener   Biscuits  \
# count    16.000000       16.000000  16.000000  15.000000  15.000000
# mean     78.562500       39.250000  78.500000  18.000000  60.666667
# std      23.145824       23.147354  18.540047  10.902162  19.841035
# min      27.000000       10.000000  40.000000   2.000000  22.000000
# 25%      71.500000       17.000000  62.500000  11.000000  56.000000
# 50%      89.000000       39.000000  84.500000  19.000000  62.000000
# 75%      96.000000       54.250000  92.250000  26.500000  75.000000
# max      98.000000       86.000000  99.000000  35.000000  91.000000
#
#        Powder_soup   Tin_soup   Potatoes  Frozen_fish  Frozen_veggies  \
# count    16.000000  16.000000  16.000000    16.000000        16.00000
# mean     49.000000  18.312500  12.750000    21.875000        15.87500
# std      15.427249  20.178268   9.574271    13.980343        12.78997
# min      27.000000   1.000000   2.000000     4.000000         2.00000
# ...

# %% [markdown]
# ## checking for null values

# %%
df.isnull()
# Out:
#     Country  Real_coffee  Instant_coffee    Tea  Sweetener  Biscuits  \
# 0     False        False           False  False      False     False
# 1     False        False           False  False      False     False
# 2     False        False           False  False      False     False
# 3     False        False           False  False      False     False
# 4     False        False           False  False      False     False
# 5     False        False           False  False      False     False
# 6     False        False           False  False      False     False
# 7     False        False           False  False      False     False
# 8     False        False           False  False      False     False
# 9     False        False           False  False      False     False
# 10    False        False           False  False      False      True
# 11    False        False           False  False      False     False
# 12    False        False           False  False      False     False
# ...

# %% [markdown]
# ## calculating no. of null values in each columns

# %%
df.isnull().sum()
# Out:
# Country           0
# Real_coffee       0
# Instant_coffee    0
# Tea               0
# Sweetener         1
# Biscuits          1
# Powder_soup       0
# Tin_soup          0
# Potatoes          0
# Frozen_fish       0
# Frozen_veggies    0
# Apples            0
# Oranges           0
# Tinned_fruit      0
# Jam               0
# Garlic            0
# Butter            0
# Margarine         0
# Olive_oil         0
# Yoghurt           1
# Crisp_bread       0
# dtype: int64

# %% [markdown]
# ## ploting all the columns versus index

# %%
df.plot()

# %% [markdown]
# ## fetching the row with the null value

# %%
df[df['Sweetener'].isnull()]
# Out:
#    Country  Real_coffee  Instant_coffee  Tea  Sweetener  Biscuits  \
# 14   Spain           70              40   40        NaN      62.0
#
#     Powder_soup  Tin_soup  Potatoes  Frozen_fish  ...  Apples  Oranges  \
# 14           43         2        14           23  ...      59       77
#
#     Tinned_fruit  Jam  Garlic  Butter  Margarine  Olive_oil  Yoghurt  \
# 14            30   38      86      44         51         91     16.0
#
#     Crisp_bread
# 14           13
#
# [1 rows x 21 columns]

# %% [markdown]
# ## fetching the row with the null value

# %%
df[df['Biscuits'].isnull()]
# Out:
#    Country  Real_coffee  Instant_coffee  Tea  Sweetener  Biscuits  \
# 10  Sweden           97              13   93       31.0       NaN
#
#     Powder_soup  Tin_soup  Potatoes  Frozen_fish  ...  Apples  Oranges  \
# 10           43        43        39           54  ...      56       78
#
#     Tinned_fruit  Jam  Garlic  Butter  Margarine  Olive_oil  Yoghurt  \
# 10            53   75       9      68         32         48      2.0
#
#     Crisp_bread
# 10           93
#
# [1 rows x 21 columns]

# %% [markdown]
# ## fetching the row with the null value

# %%
df[df['Yoghurt'].isnull()]
# Out:
#     Country  Real_coffee  Instant_coffee  Tea  Sweetener  Biscuits  \
# 13  Finland           98              12   84       20.0      64.0
#
#     Powder_soup  Tin_soup  Potatoes  Frozen_fish  ...  Apples  Oranges  \
# 13           27        10         8           18  ...      50       57
#
#     Tinned_fruit  Jam  Garlic  Butter  Margarine  Olive_oil  Yoghurt  \
# 13            22   37      15      96         94         17      NaN
#
#     Crisp_bread
# 13           64
#
# [1 rows x 21 columns]

# %% [markdown]
# ## replacing NaN value with the mean of that particular column

# %%
df['Sweetener'].fillna(value = round(df['Sweetener'].mean(),2),inplace = True)

# %% [markdown]
# ## replacing NaN value with the mean of that particular column

# %%
df['Biscuits'].fillna(value = round(df['Biscuits'].mean(),2),inplace = True)

# %% [markdown]
# ## replacing NaN value with the mean of that particular column

# %%
df['Yoghurt'].fillna(value = round(df['Yoghurt'].mean(),2),inplace = True)

# %% [markdown]
# ## after replacing NaN values verifying if any null values are present

# %%
df.isnull().sum()
# Out:
# Country           0
# Real_coffee       0
# Instant_coffee    0
# Tea               0
# Sweetener         0
# Biscuits          0
# Powder_soup       0
# Tin_soup          0
# Potatoes          0
# Frozen_fish       0
# Frozen_veggies    0
# Apples            0
# Oranges           0
# Tinned_fruit      0
# Jam               0
# Garlic            0
# Butter            0
# Margarine         0
# Olive_oil         0
# Yoghurt           0
# Crisp_bread       0
# dtype: int64

# %% [markdown]
# ## calculating various parameters in the dataframe

# %%
df.describe()
# Out:
#        Real_coffee  Instant_coffee        Tea  Sweetener   Biscuits  \
# count    16.000000       16.000000  16.000000  16.000000  16.000000
# mean     78.562500       39.250000  78.500000  18.000000  60.666875
# std      23.145824       23.147354  18.540047  10.532489  19.168261
# min      27.000000       10.000000  40.000000   2.000000  22.000000
# 25%      71.500000       17.000000  62.500000  11.000000  56.500000
# 50%      89.000000       39.000000  84.500000  18.500000  62.000000
# 75%      96.000000       54.250000  92.250000  25.750000  74.500000
# max      98.000000       86.000000  99.000000  35.000000  91.000000
#
#        Powder_soup   Tin_soup   Potatoes  Frozen_fish  Frozen_veggies  \
# count    16.000000  16.000000  16.000000    16.000000        16.00000
# mean     49.000000  18.312500  12.750000    21.875000        15.87500
# std      15.427249  20.178268   9.574271    13.980343        12.78997
# min      27.000000   1.000000   2.000000     4.000000         2.00000
# ...

# %% [markdown]
# ## calculating Kurtosis for every column in the dataframe

# %%
df.kurtosis()
# Out:
# Real_coffee       1.019405
# Instant_coffee   -0.676180
# Tea              -0.402586
# Sweetener        -0.970910
# Biscuits          0.131851
# Powder_soup      -1.041045
# Tin_soup          3.610954
# Potatoes          2.555217
# Frozen_fish       1.506809
# Frozen_veggies    1.154756
# Apples            1.195283
# Oranges          -0.070173
# Tinned_fruit      0.104295
# Jam              -0.738795
# Garlic           -1.780691
# Butter           -0.404829
# Margarine        -1.248904
# Olive_oil        -1.621018
# Yoghurt          -0.252454
# Crisp_bread       1.950650
# dtype: float64

# %% [markdown]
# ## calculating skew values for every columns

# %%
df.skew()
# Out:
# Real_coffee      -1.393637
# Instant_coffee    0.455324
# Tea              -0.823639
# Sweetener        -0.032865
# Biscuits         -0.740399
# Powder_soup       0.411364
# Tin_soup          1.846718
# Potatoes          1.388787
# Frozen_fish       1.260095
# Frozen_veggies    1.252863
# Apples           -1.061611
# Oranges          -0.458777
# Tinned_fruit      0.458299
# Jam              -0.034342
# Garlic            0.416234
# Butter           -0.807415
# Margarine        -0.611976
# Olive_oil         0.112726
# Yoghurt           0.966839
# Crisp_bread       1.530070
# dtype: float64

# %% [markdown]
# ## boxplot of all the columns

# %%
df.boxplot()

# %% [markdown]
# ## boxplot for Tea column

# %%
plt.boxplot(df.Tea)
plt.show()

# %% [markdown]
# ## boxplot for Real_coffee column

# %%
plt.boxplot(df.Real_coffee)
plt.show()

# %% [markdown]
# ## Printing dataframe after all NaN values are replaced

# %%
df
# Out:
#         Country  Real_coffee  Instant_coffee  Tea  Sweetener  Biscuits  \
# 0       Germany           90              49   88       19.0     57.00
# 1         Italy           82              10   60        2.0     55.00
# 2        France           88              42   63        4.0     76.00
# 3       Holland           96              62   98       32.0     62.00
# 4       Belgium           94              38   48       11.0     74.00
# 5    Luxembourg           97              61   86       28.0     79.00
# 6       England           27              86   99       22.0     91.00
# 7      Portugal           72              26   77        2.0     22.00
# 8       Austria           55              31   61       15.0     29.00
# 9   Switzerland           73              72   85       25.0     31.00
# 10       Sweden           97              13   93       31.0     60.67
# 11      Denmark           96              17   92       35.0     66.00
# ...

# %% [markdown]
# ## Plot of Real_coffee column

# %%
plt.plot(df.Real_coffee)

# %% [markdown]
# ## clculating mean of Real_coffee column

# %%
np.mean(df.Real_coffee)
# Out:
# 78.5625

# %% [markdown]
# ## calculating median of Real_coffee column

# %%
np.median(df.Real_coffee)
# Out:
# 89.0

# %% [markdown]
# ## calculating mode of Real_coffee column

# %%
stats.mode(df.Real_coffee)
# Out:
# ModeResult(mode=array([96], dtype=int64), count=array([2]))

# %% [markdown]
# ## create a column with percentage of food consumed by each country

# %%
df['Consumtion_%_by_country'] = (df.sum(axis=1))/19
df
#df.columns = [c.replace(' ', '_') for c in df.columns]
# Out:
#         Country  Real_coffee  Instant_coffee  Tea  Sweetener  Biscuits  \
# 0       Germany           90              49   88       19.0     57.00
# 1         Italy           82              10   60        2.0     55.00
# 2        France           88              42   63        4.0     76.00
# 3       Holland           96              62   98       32.0     62.00
# 4       Belgium           94              38   48       11.0     74.00
# 5    Luxembourg           97              61   86       28.0     79.00
# 6       England           27              86   99       22.0     91.00
# 7      Portugal           72              26   77        2.0     22.00
# 8       Austria           55              31   61       15.0     29.00
# 9   Switzerland           73              72   85       25.0     31.00
# 10       Sweden           97              13   93       31.0     60.67
# 11      Denmark           96              17   92       35.0     66.00
# ...

# %%
#df[df.columns[2]]

# %% [markdown]
# ## sorting values of Tea column

# %%
df1 = df.sort_values('Tea')

# %% [markdown]
# ## plotting Tea column with index

# %%
plt.plot(np.arange(df1['Tea'].count()),df1.Tea)

# %% [markdown]
# ## bar plot of Tea column with index

# %%
plt.bar(np.arange(df1['Tea'].count()),df1.Tea)
# Out:
# <BarContainer object of 16 artists>

# %%
# calculating no of rows in Tea column
df['Tea'].count()
# Out:
# 16

# %%
# checkcing index of tea columns w.r.t its value
df1.Tea
# Out:
# 14    40
# 4     48
# 1     60
# 8     61
# 2     63
# 7     77
# 12    83
# 13    84
# 9     85
# 5     86
# 0     88
# 11    92
# 10    93
# 3     98
# 6     99
# 15    99
# Name: Tea, dtype: int64

# %%
# histograph for Tea column
df.hist('Tea')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000157CEC65A90>]],
#       dtype=object)
