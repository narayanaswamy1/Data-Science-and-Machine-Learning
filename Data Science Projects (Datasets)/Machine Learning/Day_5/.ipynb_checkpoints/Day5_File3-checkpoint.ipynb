# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
house = pd.read_csv('kc_house_data.csv')
house.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
house.shape
# Out:
# (21613, 21)

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# ...

# %%
house.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
house.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
house.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
fig = plt.figure()
sns.heatmap(house.corr(),annot=True,annot_kws={'size':13},ax=fig.add_axes([0,0,3,3]))

# %%
house.columns[[len(set(house[i]))==2 for i in house.columns]]
# Out:
# Index(['waterfront'], dtype='object')

# %%
house.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
house.drop(labels=['id', 'date','zipcode','waterfront','view','yr_renovated'],axis=1,inplace=True)

# %%
house.shape
# Out:
# (21613, 15)

# %%
house.skew()
# Out:
# price             4.024069
# bedrooms          1.974300
# bathrooms         0.511108
# sqft_living       1.471555
# sqft_lot         13.060019
# floors            0.616177
# condition         1.032805
# grade             0.771103
# sqft_above        1.446664
# sqft_basement     1.577965
# yr_built         -0.469805
# lat              -0.485270
# long              0.885053
# sqft_living15     1.108181
# sqft_lot15        9.506743
# dtype: float64

# %%
house.kurtosis()
# Out:
# price             34.585540
# bedrooms          49.063653
# bathrooms          1.279902
# sqft_living        5.243093
# sqft_lot         285.077820
# floors            -0.484723
# condition          0.525764
# grade              1.190932
# sqft_above         3.402304
# sqft_basement      2.715574
# yr_built          -0.657408
# lat               -0.676313
# long               1.049501
# sqft_living15      1.597096
# sqft_lot15       150.763110
# dtype: float64

# %%
plt.figure(figsize=(20,20))
a = list(house.columns)
a.remove('price')
x=1
for i in a:
    plt.subplot(6,3,x)
    plt.scatter(house[i],house['price'])
    x+=1

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=house)

# %%
plt.figure(figsize=(20,20))
z=1
for i in house.columns:
    plt.subplot(6,3,z)
    sns.distplot(house[i]) # Stack these distributions together with different colors
    z+=1

# %%
house.skew().sort_values(ascending=False)
# Out:
# sqft_lot         13.060019
# sqft_lot15        9.506743
# price             4.024069
# bedrooms          1.974300
# sqft_basement     1.577965
# sqft_living       1.471555
# sqft_above        1.446664
# sqft_living15     1.108181
# condition         1.032805
# long              0.885053
# grade             0.771103
# floors            0.616177
# bathrooms         0.511108
# yr_built         -0.469805
# lat              -0.485270
# dtype: float64

# %%
house.columns[house.skew()>1.96]
# Out:
# Index(['price', 'bedrooms', 'sqft_lot', 'sqft_lot15'], dtype='object')

# %%
house_sqft_lot = house[(house['sqft_lot']>(np.mean(house['sqft_lot'])-3*np.std(house['sqft_lot']))) & (house['sqft_lot']<(np.mean(house['sqft_lot'])+.5*np.std(house['sqft_lot'])))]
print(house_sqft_lot.shape)
plt.figure(figsize=(15,5))
sns.boxplot(house_sqft_lot)
# Out:
# (20219, 15)

# %%
house_sqft_lot15 = house_sqft_lot[(house_sqft_lot['sqft_lot15']>(np.mean(house_sqft_lot['sqft_lot15'])-3*np.std(house_sqft_lot['sqft_lot15']))) & (house_sqft_lot['sqft_lot15']<(np.mean(house_sqft_lot['sqft_lot15'])+2.15*np.std(house_sqft_lot['sqft_lot15'])))]
print(house_sqft_lot15.shape)
plt.figure(figsize=(15,5))
sns.boxplot(house_sqft_lot15)
# Out:
# (19748, 15)

# %%
house_price = house_sqft_lot15[(house_sqft_lot15['price']>(np.mean(house_sqft_lot15['price'])-3*np.std(house_sqft_lot15['price']))) & (house_sqft_lot15['price']<(np.mean(house_sqft_lot15['price'])+2.15*np.std(house_sqft_lot15['price'])))]
print(house_price.shape)
plt.figure(figsize=(15,5))
sns.boxplot(house_price)
# Out:
# (19039, 15)

# %%
house_bedrooms = house_price[(house_price['bedrooms']>(np.mean(house_price['bedrooms'])-3*np.std(house_price['bedrooms']))) & (house_price['bedrooms']<(np.mean(house_price['bedrooms'])+2*np.std(house_price['bedrooms'])))]
print(house_bedrooms.shape)
plt.figure(figsize=(15,5))
sns.boxplot(house_bedrooms)
# Out:
# (18768, 15)

# %%
house_bedrooms.skew().sort_values(ascending=False)
# Out:
# sqft_lot         1.693271
# sqft_basement    1.395406
# sqft_above       1.137815
# condition        1.055839
# sqft_lot15       1.035859
# sqft_living15    1.030993
# price            1.006077
# long             0.982102
# sqft_living      0.841165
# floors           0.710107
# grade            0.558877
# bathrooms        0.129507
# bedrooms         0.054325
# yr_built        -0.407836
# lat             -0.470255
# dtype: float64

# %%
fig = plt.figure()
sns.heatmap(house_bedrooms.corr(),annot=True,annot_kws={'size':13},ax=fig.add_axes([0,0,3,3]))

# %%
from sklearn.model_selection import train_test_split

# %%
house_bedrooms_train, house_bedrooms_test = train_test_split(house_bedrooms,test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
house_bedrooms_train_scaled = pd.DataFrame(sc.fit_transform(house_bedrooms_train),columns=house_bedrooms.columns)

# %%
house_bedrooms_test_scaled = pd.DataFrame(sc.fit_transform(house_bedrooms_test),columns=house_bedrooms.columns)

# %%
print(house_bedrooms_train_scaled.shape)
# Out:
# (13137, 15)

# %%
print(house_bedrooms_test_scaled.shape)
# Out:
# (5631, 15)

# %%
X_train = house_bedrooms_train_scaled.drop('price',axis=1)
X_test = house_bedrooms_test_scaled.drop('price',axis=1)

# %%
y_train = house_bedrooms_train_scaled.price
y_test = house_bedrooms_test_scaled.price

# %%
from sklearn.feature_selection import RFE

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
rfe = RFE(lr,10)

# %%
rfe = rfe.fit(X_train,y_train)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('bedrooms', False, 3),
#  ('bathrooms', False, 2),
#  ('sqft_living', True, 1),
#  ('sqft_lot', False, 4),
#  ('floors', True, 1),
#  ('condition', True, 1),
#  ('grade', True, 1),
#  ('sqft_above', True, 1),
#  ('sqft_basement', True, 1),
#  ('yr_built', True, 1),
#  ('lat', True, 1),
#  ('long', False, 5),
#  ('sqft_living15', True, 1),
#  ('sqft_lot15', True, 1)]

# %%
rfe.support_
# Out:
# array([False, False,  True, False,  True,  True,  True,  True,  True,
#         True,  True, False,  True,  True])

# %%
rfe.ranking_
# Out:
# array([3, 2, 1, 4, 1, 1, 1, 1, 1, 1, 1, 5, 1, 1])

# %%
selected_col = X_train.columns[rfe.support_]

# %%
selected_col
# Out:
# Index(['sqft_living', 'floors', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'lat', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
X_train_rfe = X_train[selected_col]

# %%
X_train_rfe.head(5)
# Out:
#    sqft_living    floors  condition     grade  sqft_above  sqft_basement  \
# 0    -1.125717 -0.880749   0.897301 -0.490251   -0.828629      -0.658714
# 1    -0.562462 -0.880749   0.897301 -0.490251   -0.943639       0.593502
# 2    -0.602694 -0.880749  -0.630017 -0.490251   -0.267956      -0.658714
# 3     0.805446  2.808498  -0.630017  1.475393    0.623370       0.418191
# 4    -0.844090 -0.880749  -0.630017 -0.490251   -1.101778       0.343058
#
#    yr_built       lat  sqft_living15  sqft_lot15
# 0 -0.406154  0.149114       0.200624    0.439635
# 1 -0.238591 -1.681478      -0.992754    0.297998
# 2 -0.607229  0.220107       1.277980    0.933148
# 3  1.437039  0.543920       0.449245   -1.381164
# 4  0.766787 -0.171801      -0.976180   -1.012965

# %%
import statsmodels.api as sm

# %%
X_train_rfe_sm = sm.add_constant(X_train_rfe)

# %%
linmod = sm.OLS(y_train,X_train_rfe_sm).fit()

# %%
print(linmod.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.689
# Model:                            OLS   Adj. R-squared:                  0.689
# Method:                 Least Squares   F-statistic:                     3237.
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):               0.00
# Time:                        17:55:52   Log-Likelihood:                -10961.
# No. Observations:               13137   AIC:                         2.194e+04
# Df Residuals:                   13127   BIC:                         2.202e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -1.041e-16      0.005  -2.14e-14      1.000      -0.010       0.010
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif['Features'] = X_train_rfe_sm.columns
vif['VIF'] = [variance_inflation_factor(X_train_rfe_sm.values, i) for i in range(X_train_rfe_sm.shape[1])]
vif['VIF'] = round(vif['VIF'],2)
vif = vif.sort_values(by = 'VIF', ascending = False)
print(vif)
# Out:
#          Features   VIF
# 1     sqft_living   inf
# 5      sqft_above   inf
# 6   sqft_basement   inf
# 9   sqft_living15  2.78
# 4           grade  2.68
# 2          floors  2.23
# 7        yr_built  1.77
# 10     sqft_lot15  1.43
# 3       condition  1.20
# 8             lat  1.12
# 0           const  1.00

# %%
X_train_rfe_sm.drop('sqft_basement',axis=1,inplace=True)

# %%
linmod1 = sm.OLS(y_train,X_train_rfe_sm).fit()
print(linmod1.summary())

vif = pd.DataFrame()
vif['Features'] = X_train_rfe_sm.columns
vif['VIF'] = [variance_inflation_factor(X_train_rfe_sm.values, i) for i in range(X_train_rfe_sm.shape[1])]
vif['VIF'] = round(vif['VIF'],2)
vif = vif.sort_values(by = 'VIF', ascending = False)
print(vif)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.689
# Model:                            OLS   Adj. R-squared:                  0.689
# Method:                 Least Squares   F-statistic:                     3237.
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):               0.00
# Time:                        17:55:53   Log-Likelihood:                -10961.
# No. Observations:               13137   AIC:                         2.194e+04
# Df Residuals:                   13127   BIC:                         2.202e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -1.041e-16      0.005  -2.14e-14      1.000      -0.010       0.010
# ...

# %%
y_train_sm_pred = linmod1.predict(X_train_rfe_sm)

# %%
error = y_train-y_train_sm_pred

# %%
sns.distplot(error)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_train,y_train_sm_pred)
# Out:
# 0.6893801645394386

# %%
X_test_sm = sm.add_constant(X_test)

# %%
X_test_sm = X_test_sm[X_train_rfe_sm.columns]

# %%
y_pred_test_sm = linmod1.predict(X_test_sm)
y_pred_train_sm = linmod1.predict(X_train_rfe_sm)

# %%
r2_score(y_test,y_pred_test_sm)
# Out:
# 0.6921293878590441

# %%
lr.fit(X_train_rfe_sm,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred_Lr = lr.predict(X_test_sm)

# %%
r2_score(y_test,y_pred_Lr)
# Out:
# 0.692129387859044
