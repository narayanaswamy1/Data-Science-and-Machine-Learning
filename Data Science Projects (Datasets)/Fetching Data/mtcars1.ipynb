# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('mt_cars.csv')
df
# Out:
#                   model   mpg  cyl   disp     hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110.0  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110.0  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93.0  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110.0  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout   NaN    8  360.0  175.0  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105.0  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245.0   NaN  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62.0  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95.0   NaN  3.150  22.90   1   0
# 9              Merc 280  19.2    6    NaN  123.0  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6    NaN  3.92  3.440  18.90   1   0
# ...

# %%
df.shape
# Out:
# (32, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
# model    32 non-null object
# mpg      27 non-null float64
# cyl      32 non-null int64
# disp     24 non-null float64
# hp       25 non-null float64
# drat     26 non-null float64
# wt       28 non-null float64
# qsec     31 non-null float64
# vs       32 non-null int64
# am       32 non-null int64
# gear     32 non-null int64
# carb     32 non-null int64
# dtypes: float64(6), int64(5), object(1)
# memory usage: 3.1+ KB

# %%
df.isnull()
# Out:
#     model    mpg    cyl   disp     hp   drat     wt   qsec     vs     am  \
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False  False  False  False
# 4   False   True  False  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False  False  False
# 6   False  False  False  False  False   True  False  False  False  False
# 7   False  False  False  False  False  False  False  False  False  False
# 8   False  False  False  False  False   True  False  False  False  False
# 9   False  False  False   True  False  False  False  False  False  False
# 10  False  False  False  False   True  False  False  False  False  False
# 11  False  False  False  False   True  False  False  False  False  False
# ...

# %%
df.isnull().sum()
# Out:
# model    0
# mpg      5
# cyl      0
# disp     8
# hp       7
# drat     6
# wt       4
# qsec     1
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %%
round(100*df.isnull().sum()/len(df),2)
# Out:
# model     0.00
# mpg      15.62
# cyl       0.00
# disp     25.00
# hp       21.88
# drat     18.75
# wt       12.50
# qsec      3.12
# vs        0.00
# am        0.00
# gear      0.00
# carb      0.00
# dtype: float64

# %%
df.drop('disp',axis =1,inplace=True)
df
# Out:
#                   model   mpg  cyl     hp  drat     wt   qsec  vs  am  gear  \
# 0             Mazda RX4  21.0    6  110.0  3.90  2.620  16.46   0   1     4
# 1         Mazda RX4 Wag  21.0    6  110.0  3.90  2.875  17.02   0   1     4
# 2            Datsun 710  22.8    4   93.0  3.85  2.320  18.61   1   1     4
# 3        Hornet 4 Drive  21.4    6  110.0  3.08  3.215  19.44   1   0     3
# 4     Hornet Sportabout   NaN    8  175.0  3.15  3.440  17.02   0   0     3
# 5               Valiant  18.1    6  105.0  2.76  3.460  20.22   1   0     3
# 6            Duster 360  14.3    8  245.0   NaN  3.570  15.84   0   0     3
# 7             Merc 240D  24.4    4   62.0  3.69  3.190  20.00   1   0     4
# 8              Merc 230  22.8    4   95.0   NaN  3.150  22.90   1   0     4
# 9              Merc 280  19.2    6  123.0  3.92  3.440  18.30   1   0     4
# 10            Merc 280C  17.8    6    NaN  3.92  3.440  18.90   1   0     4
# ...

# %%
df.drop('hp',axis =1,inplace=True)
df
# Out:
#                   model   mpg  cyl  drat     wt   qsec  vs  am  gear  carb
# 0             Mazda RX4  21.0    6  3.90  2.620  16.46   0   1     4     4
# 1         Mazda RX4 Wag  21.0    6  3.90  2.875  17.02   0   1     4     4
# 2            Datsun 710  22.8    4  3.85  2.320  18.61   1   1     4     1
# 3        Hornet 4 Drive  21.4    6  3.08  3.215  19.44   1   0     3     1
# 4     Hornet Sportabout   NaN    8  3.15  3.440  17.02   0   0     3     2
# 5               Valiant  18.1    6  2.76  3.460  20.22   1   0     3     1
# 6            Duster 360  14.3    8   NaN  3.570  15.84   0   0     3     4
# 7             Merc 240D  24.4    4  3.69  3.190  20.00   1   0     4     2
# 8              Merc 230  22.8    4   NaN  3.150  22.90   1   0     4     2
# 9              Merc 280  19.2    6  3.92  3.440  18.30   1   0     4     4
# 10            Merc 280C  17.8    6  3.92  3.440  18.90   1   0     4     4
# ...

# %%
df[df.isnull().sum(axis=1)==2].shape
# Out:
# (4, 10)

# %%
df[df.isnull().sum(axis=1)==2]
# Out:
#                  model   mpg  cyl  drat     wt   qsec  vs  am  gear  carb
# 12          Merc 450SL   NaN    8   NaN  3.730  17.60   0   0     3     3
# 14  Cadillac Fleetwood  10.4    8   NaN    NaN  17.98   0   0     3     4
# 19      Toyota Corolla  33.9    4   NaN  1.835    NaN   1   1     4     1
# 28      Ford Pantera L   NaN    8  4.22    NaN  14.50   0   1     5     4

# %%
df1 = df[np.isnan(df['mpg'])]
df1
# Out:
#                 model  mpg  cyl  drat     wt   qsec  vs  am  gear  carb
# 4   Hornet Sportabout  NaN    8  3.15  3.440  17.02   0   0     3     2
# 12         Merc 450SL  NaN    8   NaN  3.730  17.60   0   0     3     3
# 22        AMC Javelin  NaN    8  3.15  3.435  17.30   0   0     3     2
# 23         Camaro Z28  NaN    8  3.73  3.840  15.41   0   0     3     4
# 28     Ford Pantera L  NaN    8  4.22    NaN  14.50   0   1     5     4

# %%
df2 = df[np.isnan(df['drat'])]
df2
# Out:
#                  model   mpg  cyl  drat     wt   qsec  vs  am  gear  carb
# 6           Duster 360  14.3    8   NaN  3.570  15.84   0   0     3     4
# 8             Merc 230  22.8    4   NaN  3.150  22.90   1   0     4     2
# 12          Merc 450SL   NaN    8   NaN  3.730  17.60   0   0     3     3
# 14  Cadillac Fleetwood  10.4    8   NaN    NaN  17.98   0   0     3     4
# 19      Toyota Corolla  33.9    4   NaN  1.835    NaN   1   1     4     1
# 31          Volvo 142E  21.4    4   NaN  2.780  18.60   1   1     4     2

# %%
df3 = df[np.isnan(df['wt'])]
df3
# Out:
#                  model   mpg  cyl  drat  wt   qsec  vs  am  gear  carb
# 13         Merc 450SLC  15.2    8  3.07 NaN  18.00   0   0     3     3
# 14  Cadillac Fleetwood  10.4    8   NaN NaN  17.98   0   0     3     4
# 28      Ford Pantera L   NaN    8  4.22 NaN  14.50   0   1     5     4
# 29        Ferrari Dino  19.7    6  3.62 NaN  15.50   0   1     5     6

# %%
# df[~np.isnan(df['qsec'])] to delete row wise
df4 = df[np.isnan(df['qsec'])]
df4
# Out:
#              model   mpg  cyl  drat     wt  qsec  vs  am  gear  carb
# 19  Toyota Corolla  33.9    4   NaN  1.835   NaN   1   1     4     1

# %%
round(df['qsec'].mean(),2)
# Out:
# 17.78

# %%
df['qsec'].fillna(value = round(df['qsec'].mean(),2),inplace = True)

# %%
df
# Out:
#                   model   mpg  cyl  drat     wt   qsec  vs  am  gear  carb
# 0             Mazda RX4  21.0    6  3.90  2.620  16.46   0   1     4     4
# 1         Mazda RX4 Wag  21.0    6  3.90  2.875  17.02   0   1     4     4
# 2            Datsun 710  22.8    4  3.85  2.320  18.61   1   1     4     1
# 3        Hornet 4 Drive  21.4    6  3.08  3.215  19.44   1   0     3     1
# 4     Hornet Sportabout   NaN    8  3.15  3.440  17.02   0   0     3     2
# 5               Valiant  18.1    6  2.76  3.460  20.22   1   0     3     1
# 6            Duster 360  14.3    8   NaN  3.570  15.84   0   0     3     4
# 7             Merc 240D  24.4    4  3.69  3.190  20.00   1   0     4     2
# 8              Merc 230  22.8    4   NaN  3.150  22.90   1   0     4     2
# 9              Merc 280  19.2    6  3.92  3.440  18.30   1   0     4     4
# 10            Merc 280C  17.8    6  3.92  3.440  18.90   1   0     4     4
# ...

# %%
df['wt'].fillna(value = 26,inplace = True)

# %%
round(df['mpg'].mean(),2)
# Out:
# 20.84

# %%
df['mpg'].fillna(value = round(df['mpg'].mean(),2),inplace = True)

# %%
df
# Out:
#                   model    mpg  cyl  drat      wt   qsec  vs  am  gear  carb
# 0             Mazda RX4  21.00    6  3.90   2.620  16.46   0   1     4     4
# 1         Mazda RX4 Wag  21.00    6  3.90   2.875  17.02   0   1     4     4
# 2            Datsun 710  22.80    4  3.85   2.320  18.61   1   1     4     1
# 3        Hornet 4 Drive  21.40    6  3.08   3.215  19.44   1   0     3     1
# 4     Hornet Sportabout  20.84    8  3.15   3.440  17.02   0   0     3     2
# 5               Valiant  18.10    6  2.76   3.460  20.22   1   0     3     1
# 6            Duster 360  14.30    8   NaN   3.570  15.84   0   0     3     4
# 7             Merc 240D  24.40    4  3.69   3.190  20.00   1   0     4     2
# 8              Merc 230  22.80    4   NaN   3.150  22.90   1   0     4     2
# 9              Merc 280  19.20    6  3.92   3.440  18.30   1   0     4     4
# 10            Merc 280C  17.80    6  3.92   3.440  18.90   1   0     4     4
# ...

# %%
round(df['drat'].mean(),2)
# Out:
# 3.6

# %%
df['drat'].fillna(value = round(df['drat'].mean(),2),inplace = True)

# %%
df
# Out:
#                   model    mpg  cyl  drat      wt   qsec  vs  am  gear  carb
# 0             Mazda RX4  21.00    6  3.90   2.620  16.46   0   1     4     4
# 1         Mazda RX4 Wag  21.00    6  3.90   2.875  17.02   0   1     4     4
# 2            Datsun 710  22.80    4  3.85   2.320  18.61   1   1     4     1
# 3        Hornet 4 Drive  21.40    6  3.08   3.215  19.44   1   0     3     1
# 4     Hornet Sportabout  20.84    8  3.15   3.440  17.02   0   0     3     2
# 5               Valiant  18.10    6  2.76   3.460  20.22   1   0     3     1
# 6            Duster 360  14.30    8  3.60   3.570  15.84   0   0     3     4
# 7             Merc 240D  24.40    4  3.69   3.190  20.00   1   0     4     2
# 8              Merc 230  22.80    4  3.60   3.150  22.90   1   0     4     2
# 9              Merc 280  19.20    6  3.92   3.440  18.30   1   0     4     4
# 10            Merc 280C  17.80    6  3.92   3.440  18.90   1   0     4     4
# ...

# %%
round(df['wt'].mean(),2)
# Out:
# 6.0

# %%
df['wt'].fillna(value = round(df['wt'].mean(),2),inplace = True)

# %%
df
# Out:
#                   model    mpg  cyl  drat      wt   qsec  vs  am  gear  carb
# 0             Mazda RX4  21.00    6  3.90   2.620  16.46   0   1     4     4
# 1         Mazda RX4 Wag  21.00    6  3.90   2.875  17.02   0   1     4     4
# 2            Datsun 710  22.80    4  3.85   2.320  18.61   1   1     4     1
# 3        Hornet 4 Drive  21.40    6  3.08   3.215  19.44   1   0     3     1
# 4     Hornet Sportabout  20.84    8  3.15   3.440  17.02   0   0     3     2
# 5               Valiant  18.10    6  2.76   3.460  20.22   1   0     3     1
# 6            Duster 360  14.30    8  3.60   3.570  15.84   0   0     3     4
# 7             Merc 240D  24.40    4  3.69   3.190  20.00   1   0     4     2
# 8              Merc 230  22.80    4  3.60   3.150  22.90   1   0     4     2
# 9              Merc 280  19.20    6  3.92   3.440  18.30   1   0     4     4
# 10            Merc 280C  17.80    6  3.92   3.440  18.90   1   0     4     4
# ...

# %%
df.isnull().sum()
# Out:
# model    0
# mpg      0
# cyl      0
# drat     0
# wt       0
# qsec     0
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 10 columns):
# model    32 non-null object
# mpg      32 non-null float64
# cyl      32 non-null int64
# drat     32 non-null float64
# wt       32 non-null float64
# qsec     32 non-null float64
# vs       32 non-null int64
# am       32 non-null int64
# gear     32 non-null int64
# carb     32 non-null int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 2.6+ KB

# %%
df[df['cyl']==6]
# Out:
#              model   mpg  cyl  drat      wt   qsec  vs  am  gear  carb
# 0        Mazda RX4  21.0    6  3.90   2.620  16.46   0   1     4     4
# 1    Mazda RX4 Wag  21.0    6  3.90   2.875  17.02   0   1     4     4
# 3   Hornet 4 Drive  21.4    6  3.08   3.215  19.44   1   0     3     1
# 5          Valiant  18.1    6  2.76   3.460  20.22   1   0     3     1
# 9         Merc 280  19.2    6  3.92   3.440  18.30   1   0     4     4
# 10       Merc 280C  17.8    6  3.92   3.440  18.90   1   0     4     4
# 29    Ferrari Dino  19.7    6  3.62  26.000  15.50   0   1     5     6

# %%
df[df['cyl']==6]['disp'].isnull().fillna(value = df[df['cyl']==6]['disp'].mean(),inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'disp'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-aa58b701a5a1> in <module>
# ...

# %%
df[df['cyl']==6]['disp'].mean()

# %%
df[df['cyl']==6].mean()

# %%
df[df['cyl']==6]

# %%
df[df['cyl']==6]['disp'].isnull()

# %%
df[[]]
