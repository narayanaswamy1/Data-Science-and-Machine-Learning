# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('mt_cars.csv')
df
# Out:
#                   model   mpg  cyl   disp     hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110.0  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110.0  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93.0  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110.0  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout   NaN    8  360.0  175.0  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105.0  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245.0   NaN  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62.0  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95.0   NaN  3.150  22.90   1   0
# 9              Merc 280  19.2    6    NaN  123.0  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6    NaN  3.92  3.440  18.90   1   0
# ...

# %%
df['disp'][df['cyl']==6].isnull().fillna(value = df[df['cyl']==6]['disp'].mean(),inplace=True)

# %%
df[df['cyl']==6]
# Out:
#              model   mpg  cyl   disp     hp  drat     wt   qsec  vs  am  gear  \
# 0        Mazda RX4  21.0    6  160.0  110.0  3.90  2.620  16.46   0   1     4
# 1    Mazda RX4 Wag  21.0    6  160.0  110.0  3.90  2.875  17.02   0   1     4
# 3   Hornet 4 Drive  21.4    6  258.0  110.0  3.08  3.215  19.44   1   0     3
# 5          Valiant  18.1    6  225.0  105.0  2.76  3.460  20.22   1   0     3
# 9         Merc 280  19.2    6    NaN  123.0  3.92  3.440  18.30   1   0     4
# 10       Merc 280C  17.8    6  167.6    NaN  3.92  3.440  18.90   1   0     4
# 29    Ferrari Dino  19.7    6  145.0  175.0  3.62    NaN  15.50   0   1     5
#
#     carb
# 0      4
# 1      4
# 3      1
# 5      1
# 9      4
# 10     4
# 29     6

# %%
df['disp'][df['cyl']==6]
# Out:
# 0     160.0
# 1     160.0
# 3     258.0
# 5     225.0
# 9       NaN
# 10    167.6
# 29    145.0
# Name: disp, dtype: float64

# %%
null_columns=df.columns[df.isnull().any()]
df[df['disp'].isnull()].fillna(value = df[df['cyl']==6]['disp'].mean(),inplace=True)
# Out:
# C:\Users\Narayana Swamy\Anaconda3\lib\site-packages\pandas\core\frame.py:4034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)

# %%
df['disp'][df['cyl']==6]
# Out:
# 0     160.0
# 1     160.0
# 3     258.0
# 5     225.0
# 9       NaN
# 10    167.6
# 29    145.0
# Name: disp, dtype: float64

# %%
df[df['cyl']==6]
# Out:
#              model   mpg  cyl   disp     hp  drat     wt   qsec  vs  am  gear  \
# 0        Mazda RX4  21.0    6  160.0  110.0  3.90  2.620  16.46   0   1     4
# 1    Mazda RX4 Wag  21.0    6  160.0  110.0  3.90  2.875  17.02   0   1     4
# 3   Hornet 4 Drive  21.4    6  258.0  110.0  3.08  3.215  19.44   1   0     3
# 5          Valiant  18.1    6  225.0  105.0  2.76  3.460  20.22   1   0     3
# 9         Merc 280  19.2    6    NaN  123.0  3.92  3.440  18.30   1   0     4
# 10       Merc 280C  17.8    6  167.6    NaN  3.92  3.440  18.90   1   0     4
# 29    Ferrari Dino  19.7    6  145.0  175.0  3.62    NaN  15.50   0   1     5
#
#     carb
# 0      4
# 1      4
# 3      1
# 5      1
# 9      4
# 10     4
# 29     6

# %%
df['c1'].loc[df['c1'] == 'Value'] = 10
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'c1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-6d4a3baa3563> in <module>
# ----> 1 df['c1'].loc[df['c1'] == 'Value'] = 10
#
# ...

# %%
#df['disp'] = np.where(df.cyl == 6,'Z','Y')

# %%
df[df['disp'].isnull()==True] = np.where(df.cyl == 6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-133105770db1> in <module>
# ----> 1 df[df['disp'].isnull()==True] = np.where(df.cyl == 6)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3365             self._setitem_frame(key, value)
#    3366         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3367             self._setitem_array(key, value)
#    3368         else:
#    3369             # set column
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    3383             indexer = key.nonzero()[0]
#    3384             self._check_setitem_copy()
# -> 3385             self.loc._setitem_with_indexer(indexer, value)
#    3386         else:
#    3387             if isinstance(value, DataFrame):
#
# ...

# %%
df[df['cyl']==6]
# Out:
#              model   mpg  cyl   disp     hp  drat     wt   qsec  vs  am  gear  \
# 0        Mazda RX4  21.0    6  160.0  110.0  3.90  2.620  16.46   0   1     4
# 1    Mazda RX4 Wag  21.0    6  160.0  110.0  3.90  2.875  17.02   0   1     4
# 3   Hornet 4 Drive  21.4    6  258.0  110.0  3.08  3.215  19.44   1   0     3
# 5          Valiant  18.1    6  225.0  105.0  2.76  3.460  20.22   1   0     3
# 9         Merc 280  19.2    6    NaN  123.0  3.92  3.440  18.30   1   0     4
# 10       Merc 280C  17.8    6  167.6    NaN  3.92  3.440  18.90   1   0     4
# 29    Ferrari Dino  19.7    6  145.0  175.0  3.62    NaN  15.50   0   1     5
#
#     carb
# 0      4
# 1      4
# 3      1
# 5      1
# 9      4
# 10     4
# 29     6

# %%
df[(df['disp'].isnull()==True) & (df['cyl']==6)]
# Out:
#       model   mpg  cyl  disp     hp  drat    wt  qsec  vs  am  gear  carb
# 9  Merc 280  19.2    6   NaN  123.0  3.92  3.44  18.3   1   0     4     4

# %%
df[(df['disp'].isnull()==True) & (df['cyl']==6)].fillna(value = df[df['cyl']==6]['disp'].mean(),inplace=True)

# %%
df[df['cyl']==6]
# Out:
#              model   mpg  cyl   disp     hp  drat     wt   qsec  vs  am  gear  \
# 0        Mazda RX4  21.0    6  160.0  110.0  3.90  2.620  16.46   0   1     4
# 1    Mazda RX4 Wag  21.0    6  160.0  110.0  3.90  2.875  17.02   0   1     4
# 3   Hornet 4 Drive  21.4    6  258.0  110.0  3.08  3.215  19.44   1   0     3
# 5          Valiant  18.1    6  225.0  105.0  2.76  3.460  20.22   1   0     3
# 9         Merc 280  19.2    6    NaN  123.0  3.92  3.440  18.30   1   0     4
# 10       Merc 280C  17.8    6  167.6    NaN  3.92  3.440  18.90   1   0     4
# 29    Ferrari Dino  19.7    6  145.0  175.0  3.62    NaN  15.50   0   1     5
#
#     carb
# 0      4
# 1      4
# 3      1
# 5      1
# 9      4
# 10     4
# 29     6

# %%
df['drat'].fillna(value = round(df['drat'].mean(),2),inplace = True)

# %%
df2 = df[np.isnan(df['drat'])]
df2
# Out:
#                  model   mpg  cyl   disp     hp  drat     wt   qsec  vs  am  \
# 6           Duster 360  14.3    8  360.0  245.0   NaN  3.570  15.84   0   0
# 8             Merc 230  22.8    4  140.8   95.0   NaN  3.150  22.90   1   0
# 12          Merc 450SL   NaN    8  275.8  180.0   NaN  3.730  17.60   0   0
# 14  Cadillac Fleetwood  10.4    8    NaN    NaN   NaN    NaN  17.98   0   0
# 19      Toyota Corolla  33.9    4   71.1    NaN   NaN  1.835    NaN   1   1
# 31          Volvo 142E  21.4    4    NaN  109.0   NaN  2.780  18.60   1   1
#
#     gear  carb
# 6      3     4
# 8      4     2
# 12     3     3
# 14     3     4
# 19     4     1
# 31     4     2

# %%
df1 = df[np.isnan(df['disp']) & (df['cyl']==6)]['disp'].fillna(0)

# %%
df['disp'] = df.where(df.cyl==6, ['X' ,'Y'])

# %%
df[df['cyl']==6]
